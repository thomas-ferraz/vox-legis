# %%
# !pip install textract

# %%
import textract
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
PATH = '/content/drive/Shared drives/NLP Jurídico - Lab. Ciência de Dados/Dados PDFs Falencias'


df = pd.DataFrame(columns=['name','text'])
df = pd.DataFrame(columns=['n_processo', 'tipo_documento', 'string', 'data_doc', 'n_folha_inicio', 'n_folha_fim'])

processos = listdir(PATH)

for processo in processos[:2]: # Para cada processo da lista de processos
  PATH_processo = PATH + '/' + processo
  arquivos = [f for f in listdir(PATH_processo) if isfile(join(PATH_processo, f))]
  pastas = [f for f in listdir(PATH_processo) if not isfile(join(PATH_processo, f))]

  for pasta in pastas[:5000]: # Para cada pasta dentro do processo
      PATH_pasta = PATH_processo + '/' + pasta
      arquivos_pasta = [f for f in listdir(PATH_pasta) if isfile(join(PATH_pasta, f))]
      for arquivo in arquivos_pasta[:5000]: # Para cada PDF nesta nova pasta
        #Faça algo com os PDFs desta pasta
        #Exemplo:
        try:
          if (len(arquivo) > 4 and arquivo[len(arquivo)-4:len(arquivo)] == '.pdf'):
            text = textract.process(PATH_pasta + '/' + arquivo)
            df = df.append({'name':arquivo,'text':text},ignore_index=True)
            print('Nome do arquivo adicionado: ',arquivo)
            print(df.shape)
        except:
          pass
# Out:
# ['Petição (pag 1 - 6).pdf', 'Procuração (pag 7).pdf', 'Guia de Custas (pag 34).pdf', 'Guia de Custas (pag 35).pdf', 'Guia de Custas (pag 36).pdf', 'Guia de Custas (pag 37).pdf', 'Guia de Custas (pag 38).pdf', 'Guia de Custas (pag 39).pdf', 'Guia de Custas (pag 40 - 41).pdf', 'Guia de Custas (pag 42 - 43).pdf', 'Documento 1 (pag 44 - 46).pdf', 'Documento 2 (pag 47 - 49).pdf', 'Documento 2 (pag 50).pdf', 'Documento 2 (pag 51).pdf', 'Documento 2 (pag 52).pdf', 'Documento 2 (pag 53 - 57).pdf', 'Documento 2 (pag 58).pdf', 'Documento 2 (pag 59 - 63).pdf', 'Documento 2 (pag 64 - 68).pdf', 'Documento 2 (pag 69 - 70).pdf', 'Decisão (pag 71).pdf', 'Certidões de Cartório (pag 72).pdf', 'Petição (pag 73).pdf', 'Procuração (pag 74).pdf', 'Documento 1 (pag 92 - 93).pdf', 'Documento 1 (pag 94).pdf', 'Documento 2 (pag 95 - 98).pdf', 'Documento 3 (pag 99 - 103).pdf', 'Documento 4 (pag 104 - 107).pdf', 'Documento 4 (pag 108 - 109).pdf', 'Documento 5 (pag 110 - 114).pdf', 'Documento 6 (pag 1
# ...

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
df = pd.DataFrame(columns=['name','text'])
PATH = '/content/drive/Shared drives/NLP Jurídico - Lab. Ciência de Dados/Dados PDFs Falencias'
processos = listdir(PATH)

for processo in processos: # Para cada processo da lista de processos
  PATH_processo = PATH + '/' + processo
  arquivos = [f for f in listdir(PATH_processo) if isfile(join(PATH_processo, f))]
  pastas = [f for f in listdir(PATH_processo) if not isfile(join(PATH_processo, f))]
  for pasta in pastas: # Para cada pasta dentro do processo
      PATH_pasta = PATH_processo + '/' + pasta
      arquivos_pasta = [f for f in listdir(PATH_pasta) if isfile(join(PATH_pasta, f))]
      for arquivo in arquivos_pasta: # Para cada PDF nesta nova pasta
        #Faça algo com os PDFs desta pasta
        #Exemplo:
        if (len(arquivo) > 4 and arquivo[len(arquivo)-4:len(arquivo)] == '.pdf' and len(df)<=3000):
          text = textract.process(PATH_pasta + '/' + arquivo)
          #print(text)
  
        for arquivo in arquivos: # Para cada PDF na pasta raíz (isto é, na lista arquivos)
          #Faça algo com os PDFs desta pasta
          #Exemplo:
          
          if (len(arquivo) > 4 and arquivo[len(arquivo)-4:len(arquivo)] == '.pdf'and len(df)<=3000):
            try:
                text = textract.process(PATH_processo + '/' + arquivo)
                df = df.append({'name':arquivo,'text':text},ignore_index=True)
                print('Nome do arquivo adicionado: ',arquivo)
                
            except:
              pass
          else:
            break
# Out:
# (0, 2)
# Nome do arquivo adicionado:  Ato Ordinatório (pag 1).pdf
# (1, 2)
# Nome do arquivo adicionado:  Administrativa (pag 2).pdf
# (2, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 3).pdf
# (3, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 4).pdf
# (4, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 5).pdf
# (5, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 6).pdf
# (6, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 7).pdf
# (7, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 8).pdf
# (8, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 9).pdf
# (9, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 10).pdf
# (10, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 11).pdf
# (11, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 12).pdf
# (12, 2)
# Nome do arquivo adicionado:  Petições Diversas (pag 13).pdf
# (13, 2)
# ...

# %%
#Montar o drive antes de rodar esta célula

from os import listdir
from os.path import isfile, join
import pandas as pd
df = pd.DataFrame(columns=['name','text'])
PATH = '/content/drive/Shared drives/NLP Jurídico - Lab. Ciência de Dados/Dados PDFs Falencias'
processos = listdir(PATH)

for processo in processos: # Para cada processo da lista de processos
  PATH_processo = PATH + '/' + processo
  arquivos = [f for f in listdir(PATH_processo) if isfile(join(PATH_processo, f))]
  pastas = [f for f in listdir(PATH_processo) if not isfile(join(PATH_processo, f))]

  for pasta in pastas: # Para cada pasta dentro do processo
    PATH_pasta = PATH_processo + '/' + pasta
    arquivos_pasta = [f for f in listdir(PATH_pasta) if isfile(join(PATH_pasta, f))]
    for arquivo in arquivos_pasta: # Para cada PDF nesta nova pasta
      #Faça algo com os PDFs desta pasta
      #Exemplo:
      if (len(arquivo) > 4 and arquivo[len(arquivo)-4:len(arquivo)] == '.pdf'):
        try:
          text = textract.process(PATH_processo + '/' + arquivo)
          df = df.append({'name':arquivo,'text':text},ignore_index=True)
          print('Nome do arquivo adicionado: ',arquivo)
          print(df.shape)
          if len(df)>=3000:
            break
        except:
          pass

# %%
df
# Out:
# Empty DataFrame
# Columns: [n_processo, tipo_documento, string, data_doc, n_folha_inicio, n_folha_fim]
# Index: []

# %%
# Pedro
from os import listdir
from os.path import isfile, join
import pandas as pd
PATH = '/content/drive/Shared drives/NLP Jurídico - Lab. Ciência de Dados/Dados PDFs Falencias'

df = pd.DataFrame(columns=['n_processo', 'tipo_documento', 'string', 'data_doc', 'assinado_por', 'n_folha_inicio', 'n_folha_fim'])

processos = listdir(PATH)

for processo in processos[:100]: # Para cada processo da lista de processos
    PATH_processo = PATH + '/' + processo
    arquivos = [f for f in listdir(PATH_processo) if isfile(join(PATH_processo, f))]
    pastas = [f for f in listdir(PATH_processo) if not isfile(join(PATH_processo, f))]

    for arquivo in arquivos[:4]:
        try: 
            index_ini_parent = arquivo.find('(')
            tipo_documento = arquivo[:index_ini_parent-1]
            n_folha_inicio = 0
            n_folha_fim = 0
            nome_assinador = ''

            pag_encontrada = False
            nome_do_arquivo = arquivo[index_ini_parent:]

            '''
            Pega a folha de inicio e de fim do nome do arquivo
            '''
            # Tenta pegar o que está dentro de dois parenteses (...). Se não tiver a 
            # string "pag", tenta pegar mais dois parenteses (...) no nome do arquivo.
            # Isso se faz importante, pois, há nomes de arquivo com coisas do tipo:
            # Blablabla (AR) (pag. xxx - xxx).pdf
            while(not pag_encontrada):
                index_ini_parent = nome_do_arquivo.find('(')
                index_fim_parent = nome_do_arquivo.find(')')
                
                # Checa se ainda há substrings com "(...)""
                if index_ini_parent != -1:
                  # Checa se a substring há algo do tipo "(pag)"
                  if 'pag' in nome_do_arquivo[index_ini_parent:index_fim_parent]: 
                      pag_encontrada = True
                      # Checa se tem uma ou duas páginas descrita no nome do arquivo
                      index_traco = nome_do_arquivo.find('-')
                      if index_traco != -1: 
                          n_folha_inicio = int(nome_do_arquivo[index_ini_parent+4:index_traco-1])
                          n_folha_fim = int(nome_do_arquivo[index_traco+1:index_fim_parent])
                      else: 
                          n_folha_inicio = int(nome_do_arquivo[index_ini_parent+4:index_fim_parent])
                          n_folha_fim = int(nome_do_arquivo[index_ini_parent+4:index_fim_parent])
                else: 
                    pag_encontrada = True
                nome_do_arquivo = nome_do_arquivo[index_fim_parent+1:]

            '''
            Extrai string do PDF
            '''
            if (len(arquivo) > 4 and arquivo[-4:] == '.pdf'):
                text = textract.process(PATH_processo + '/' + arquivo)
                text = text.decode("utf-8")
                data_doc = ''
                '''
                Tenta encontrar data da assinatura do documento
                '''
                index_date = text.find("protocolado em")
                if index_date != -1:
                    data_doc = text[index_date+15:index_date+25]
                else: 
                    index_date = text.find("liberado nos autos em")
                    if index_date != -1: 
                        data_doc = text[index_date+22:index_date+32]
                '''
                Tenta encontrar quem assinou o documento 
                '''
                index_name = text.find("assinado digitalmente por")
                if index_name != -1:
                    index_end_name = text[index_name:].find(',')
                    nome_assinador = text[index_name+26:index_name+index_end_name]

            df = df.append({'n_processo': processo, 'tipo_documento': tipo_documento,
                            'string': text, 'data_doc': data_doc, 'assinado_por': nome_assinador,'n_folha_inicio': n_folha_inicio, 
                            'n_folha_fim':n_folha_fim}, ignore_index=True)
            print(arquivo)
            print(processo, tipo_documento, data_doc, n_folha_inicio, n_folha_fim)
        except: 
            print('Problema ocorreu ao processar o seguinte documento: ')
            print(arquivo)
            pass
# Out:
# Petição (pag 1 - 6).pdf
# 1083182-96.2016.8.26.0100 Petição 05/08/2016 1 6
# Procuração (pag 7).pdf
# 1083182-96.2016.8.26.0100 Procuração 05/08/2016 7 7
# Guia de Custas (pag 34).pdf
# 1083182-96.2016.8.26.0100 Guia de Custas 05/08/2016 34 34
# Guia de Custas (pag 35).pdf
# 1083182-96.2016.8.26.0100 Guia de Custas 05/08/2016 35 35
# Petição (pag 1 - 4).pdf
# 1084043-53.2014.8.26.0100 Petição 01/09/2014 1 4
# Procuração (pag 5).pdf
# 1084043-53.2014.8.26.0100 Procuração 01/09/2014 5 5
# Documentos (pag 16 - 17).pdf
# 1084043-53.2014.8.26.0100 Documentos 01/09/2014 16 17
# Documentos (pag 18 - 19).pdf
# 1084043-53.2014.8.26.0100 Documentos 01/09/2014 18 19
# Petição (pag 1 - 4).pdf
# 1084253-36.2016.8.26.0100 Petição 08/08/2016 1 4
# Procuração (pag 5 - 6).pdf
# 1084253-36.2016.8.26.0100 Procuração 08/08/2016 5 6
# Guia de Custas (pag 11).pdf
# 1084253-36.2016.8.26.0100 Guia de Custas 08/08/2016 11 11
# Guia de Custas (pag 12).pdf
# ...

# %%
df
# Out:
#                     n_processo       tipo_documento  ... n_folha_inicio n_folha_fim
# 0    1083182-96.2016.8.26.0100            Petição  ...              1           6
# 1    1083182-96.2016.8.26.0100         Procuração  ...              7           7
# 2    1083182-96.2016.8.26.0100       Guia de Custas  ...             34          34
# 3    1083182-96.2016.8.26.0100       Guia de Custas  ...             35          35
# 4    1084043-53.2014.8.26.0100            Petição  ...              1           4
# ..                         ...                  ...  ...            ...         ...
# 390  1009903-69.2015.8.26.0114       Guia de Custas  ...              6           6
# 391  1091986-19.2017.8.26.0100            Petição  ...              1           5
# 392  1091986-19.2017.8.26.0100         Procuração  ...              6           6
# 393  1091986-19.2017.8.26.0100    Justiça Gratuita  ...              7           7
# ...

# %%
df['tipo_documento'].value_counts()
# Out:
# Petição                  106
# Procuração                83
# Documento 1                 55
# Guia de Custas              41
# Documentos                  28
# Documento 2                 22
# Documento 3                 16
# Planilha de Cálculos       11
# Documentos Pessoais         10
# Justiça Gratuita            7
# Petição Inicial            5
# Certidões de Cartório      4
# Decisão                     3
# Sentenças                   1
# Documento 5                  1
# Documento 4                  1
# Ofícios                     1
# Name: tipo_documento, dtype: int64

# %%
df[df['tipo_documento']=="Sentenças"]
# Out:
#                     n_processo tipo_documento  ... n_folha_inicio n_folha_fim
# 223  1090660-24.2017.8.26.0100     Sentenças  ...              5           5
#
# [1 rows x 7 columns]

# %%
# !git clone https://robonauta:52zoz7cZUZ1zuzmft6YB@gitlab.com/thomas-ferraz/MAC6967-G6-NLP-juridico.git drive/'My Drive'/MAC6967-G6-NLP-juridico
# Out:
# Cloning into 'drive/My Drive/MAC6967-G6-NLP-juridico'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 56 (delta 15), reused 21 (delta 5), pack-reused 6
# Unpacking objects: 100% (56/56), done.

# %%
# !ls drive/'My Drive'
# Out:
#  4_6046343461957797373.py.gdoc
# '[AGA0106] Estudos para P2.gdoc'
# 'Apresentação - Pitch.gslides'
# 'Apresentação sem título.gslides'
#  atestado_de_matricula.pdf
#  AulasSO2.gslides
# 'AutoCrat Demo Folder'
# 'Carta de comprometimento financeiro-Pedro.gdoc'
# 'Carta de comprometimento financeiro-Pedro.pdf'
# 'Carta de comprometimento financeiro-Rita.gdoc'
# 'Carta de motivação - modelo.gdoc'
# 'Carta de motivação - Universidade de Lisboa.gdoc'
# 'Carta de motivação - Università Degli Studi Di Verona.gdoc'
# 'Carta de motivação - Università della Svizzera italiana.gdoc'
# 'Certificado de participantes.gslides'
#  Certificados
# 'CERTIFICATE OF REGISTRATION.gdoc'
# "Certify'em Records.gsheet"
# 'Colab Notebooks'
#  comprovante_de_residencia.pdf
# 'Cópia de Horários 2º Semestre 2020 V1.gsheet'
#  cpf_pedro.pdf
# 'Critérios AUCANI Bolsa Mérito 2019.gdoc'
# 'Cronograma - IC.gdoc'
# 'Curriculum vitae - English.gdoc'
# 'Curriculum vitae.gdoc'
# ...

# %%
# !cp drive/'Shared drives'/'NLP Jurídico - Lab. Ciência de Dados'/'Códigos Colab'/'Abrir PDFs.ipynb' drive/'My Drive'/MAC6967-G6-NLP-juridico/
# Out:
# cp: cannot create regular file 'drive/Shared drives/NLP Jurídico - Lab. Ciência de Dados/MAC6967-G6-NLP-juridico/': Not a directory
